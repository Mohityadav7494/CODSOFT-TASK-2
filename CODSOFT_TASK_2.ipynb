# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/IMDb Movies India.csv', encoding = 'latin-1')
data.head(10)
# Out:
#                                  Name    Year Duration  \
# 0                                         NaN      NaN
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 2                         #Homecoming  (2021)   90 min
# 3                             #Yaaram  (2019)  110 min
# 4                   ...And Once Again  (2010)  105 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 7                      .in for Motion  (2008)   59 min
# 8                  ?: A Question Mark  (2012)   82 min
# 9                            @Andheri  (2014)  116 min
#
#                        Genre  Rating  Votes            Director  \
# 0                      Drama     NaN    NaN       J.S. Randhawa
# 1                      Drama     7.0      8       Gaurav Bakshi
# 2             Drama, Musical     NaN    NaN  Soumyajit Majumdar
# 3            Comedy, Romance     4.4     35          Ovais Khan
# 4                      Drama     NaN    NaN        Amol Palekar
# 5     Comedy, Drama, Musical     4.7    827        Rahul Rawail
# 6        Drama, Romance, War     7.4  1,086      Shoojit Sircar
# 7                Documentary     NaN    NaN       Anirban Datta
# 8  Horror, Mystery, Thriller     5.6    326       Allyson Patel
# 9    Action, Crime, Thriller     4.0     11   Biju Bhaskar Nair
#
#            Actor 1                 Actor 2          Actor 3
# 0         Manmauji                  Birbal  Rajendra Bhatia
# 1     Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 2     Sayani Gupta       Plabita Borthakur       Roy Angana
# 3          Prateik              Ishita Raj  Siddhant Kapoor
# 4     Rajat Kapoor      Rituparna Sengupta      Antara Mali
# 5       Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 6  Jimmy Sheirgill          Minissha Lamba   Yashpal Sharma
# 7              NaN                     NaN              NaN
# 8        Yash Dave          Muntazir Ahmad     Kiran Bhatia
# 9        Augustine            Fathima Babu             Byon

# %%
#Check the shape of data
data.shape
# Out:
# (15509, 10)

# %%
#to check the columns of data
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
# Information about data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
# To check null values in data

data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
# To drop null values

data.dropna(inplace = True)

# %%
# Top 10 values from data
data.head(10)
# Out:
#                                   Name    Year Duration  \
# 1   #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                              #Yaaram  (2019)  110 min
# 5                 ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                            ...Yahaan  (2005)  142 min
# 8                   ?: A Question Mark  (2012)   82 min
# 9                             @Andheri  (2014)  116 min
# 10           1:1.6 An Ode to Lost Love  (2004)   96 min
# 11                1:13:7 Ek Tera Saath  (2016)  120 min
# 12                            100 Days  (1991)  161 min
# 13                           100% Love  (2012)  166 min
#
#                         Genre  Rating  Votes           Director  \
# 1                       Drama     7.0      8      Gaurav Bakshi
# 3             Comedy, Romance     4.4     35         Ovais Khan
# 5      Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 6         Drama, Romance, War     7.4  1,086     Shoojit Sircar
# 8   Horror, Mystery, Thriller     5.6    326      Allyson Patel
# 9     Action, Crime, Thriller     4.0     11  Biju Bhaskar Nair
# 10                      Drama     6.2     17        Madhu Ambat
# 11                     Horror     5.9     59    Arshad Siddiqui
# 12  Horror, Romance, Thriller     6.5    983       Partho Ghosh
# 13     Comedy, Drama, Romance     5.7    512        Rabi Kinagi
#
#             Actor 1                 Actor 2          Actor 3
# 1      Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 3           Prateik              Ishita Raj  Siddhant Kapoor
# 5        Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 6   Jimmy Sheirgill          Minissha Lamba   Yashpal Sharma
# 8         Yash Dave          Muntazir Ahmad     Kiran Bhatia
# 9         Augustine            Fathima Babu             Byon
# 10   Rati Agnihotri          Gulshan Grover    Atul Kulkarni
# 11     Pankaj Berry            Anubhav Dhir     Hritu Dudani
# 12    Jackie Shroff           Madhuri Dixit    Javed Jaffrey
# 13             Jeet           Koyel Mallick      Sujoy Ghosh

# %%
# check the shape again
data.shape
# Out:
# (5659, 10)

# %%
rating_count = data['Rating'].value_counts()
top_rating = rating_count.head(10)
top_rating
# Out:
# Rating
# 6.8    200
# 6.5    192
# 6.2    190
# 6.6    163
# 7.1    163
# 6.9    161
# 6.7    159
# 7.2    158
# 6.1    156
# 7.0    154
# Name: count, dtype: int64

# %%
plt.figure(figsize = (11,6))                                                       # We can count the rtings through seaborn library as wee
top_rating.plot(kind = 'bar', color = 'blue', edgecolor = 'black')                 # sns.count(data = data, x = 'rating', color = 'red')

for index, value in enumerate(top_rating):
  plt.text(index, value + 0.1, str(value), ha = 'center')

plt.title("Count of top 10 ratings")
plt.xlabel("Ratings")
plt.ylabel('Count')
plt.show()

# %%
# to calculate average rating

average_rating = data.groupby('Year')['Rating'].mean()
top_averga_rating = average_rating.sort_values(ascending = False).head(10)
top_averga_rating
# Out:
# Year
# (1952)    7.212500
# (1957)    7.080645
# (1944)    7.075000
# (1940)    7.050000
# (1953)    6.955000
# (1946)    6.933333
# (1948)    6.920000
# (1949)    6.915385
# (1955)    6.848000
# (1961)    6.836000
# Name: Rating, dtype: float64

# %%
plt.figure(figsize = (11,6))
plt.plot(top_averga_rating.index, top_averga_rating.values, color = 'red', marker = 'o', linestyle = '--')
plt.title("Year with best rating")
plt.xlabel("Year")
plt.ylabel("Rating")
plt.grid(True)
plt.show()

# %%
# Convert year into string
data['Year'] = data['Year'].astype(str)

# %%
# Top 10 overall
top_10_overall = data.nlargest(10, 'Rating')
top_10_overall
# Out:
#                       Name    Year Duration                   Genre  Rating  \
# 8339       Love Qubool Hai  (2020)   94 min          Drama, Romance    10.0
# 5410            Half Songs  (2021)   79 min          Music, Romance     9.7
# 5077          Gho Gho Rani  (2019)  105 min        History, Romance     9.4
# 6852                  June  (2021)   93 min                   Drama     9.4
# 14222  The Reluctant Crime  (2020)  113 min                   Drama     9.4
# 1314          Ashok Vatika  (2018)   97 min                   Drama     9.3
# 1729              Baikunth  (2021)   72 min                  Family     9.3
# 5125           God of gods  (2019)   90 min             Documentary     9.3
# 8344          Love Sorries  (2021)  101 min  Comedy, Drama, Romance     9.3
# 11843              Refl3ct  (2021)   65 min                  Sci-Fi     9.3
#
#       Votes         Director            Actor 1          Actor 2  \
# 8339      5  Saif Ali Sayeed          Ahaan Jha   Mahesh Narayan
# 5410      7      Sriram Raja       Raj Banerjee  Emon Chatterjee
# 5077     47     Munni Pankaj  Nishi Neha Mishra     Pankaj Kamal
# 6852     18   Suhrud Godbole     Vaibhav Khisti   Nilesh Divekar
# 14222    16    Arvind Pratap    Dharmendra Ahir   Awanish Kotnal
# 1314      7    Rahul Mallick         Kunj Anand   Sanjay Bishnoi
# 1729     29     Vishwa Bhanu       Vishwa Bhanu    Sangam Shukla
# 5125     46     Venkatesh Bk  Tejaswini Manogna    Triyug Mantri
# 8344     79     Gautam Joshi   Prashant Chaubey  Puneet Chouksey
# 11843   467     Nikhil Mahar        Vijay Mahar      Vijay Mahar
#
#                    Actor 3
# 8339   Rajasree Rajakumari
# 5410     Purshottam Mulani
# 5077           Akash Kumar
# 6852        Jitendra Joshi
# 14222         Rakhi Mansha
# 1314          Paras Zutshi
# 1729          Vijay Thakur
# 5125       Raj Singh Verma
# 8344         Amitabh Gupta
# 11843         Nikhil Mahar

# %%
# Top 10 movies
movies_rating_per_year = data.groupby('Year').apply(lambda x: x.nlargest(10, 'Rating')).reset_index(drop = True)
top_10_movies_rating_per_year = movies_rating_per_year.head(50)
top_10_movies_rating_per_year
# Out:
#                              Name    Year Duration                      Genre  \
# 0          The Light of the World  (1931)  124 min             Drama, Fantasy
# 1                        Draupadi  (1931)  124 min                      Drama
# 2                      Indrasabha  (1932)  211 min           Musical, Romance
# 3                            Fate  (1933)   68 min             Drama, Romance
# 4                         Mazdoor  (1934)  155 min                      Drama
# 5                      Piya Pyare  (1934)  144 min         Adventure, Fantasy
# 6                        Inquilab  (1935)  144 min                      Drama
# 7                   Miss Manorama  (1935)   90 min                      Drama
# 8                       Bhikharan  (1935)  143 min                      Drama
# 9     The Princess and the Hunter  (1935)  164 min          Action, Adventure
# 10                    Chandrasena  (1935)  136 min                  Adventure
# 11                    Jeevan Naya  (1936)  140 min                      Drama
# 12                   Achhut Kanya  (1936)  142 min    Drama, Musical, Romance
# 13                         Devdas  (1936)  139 min             Drama, Romance
# 14                     Amar Jyoti  (1936)  166 min                      Drama
# 15             Miss Frontier Mail  (1936)  161 min                      Drama
# 16                    Janmabhoomi  (1936)  139 min                      Drama
# 17                  Rajput Ramani  (1936)  138 min                  Adventure
# 18                      Bidyapati  (1937)  141 min                      Drama
# 19                 Duniya Na Mane  (1937)  166 min                      Drama
# 20                   Sant Tukaram  (1937)  131 min                  Biography
# 21                    Kisan Kanya  (1937)  137 min                      Drama
# 22                    Prem Kahani  (1937)   87 min     Drama, Family, Romance
# 23                 Toofani Tarzan  (1937)  112 min                  Adventure
# 24                        Baghban  (1938)  159 min                      Drama
# 25           Teen Sau Din Ke Baad  (1938)  158 min                  Adventure
# 26                  Street Singer  (1938)  135 min                      Drama
# 27                        Nirmala  (1938)  128 min                      Drama
# 28                    Jiban Maran  (1938)  144 min             Drama, Romance
# 29                    Leatherface  (1939)  166 min          Action, Adventure
# 30       Life's for Living: Aadmi  (1939)  164 min             Drama, Romance
# 31               Sant Dnyaneshwar  (1940)  137 min                  Biography
# 32               Sant Dnyaneshwar  (1940)  139 min                    Fantasy
# 33                          Aurat  (1940)  154 min                      Drama
# 34                           Azad  (1940)  140 min                      Drama
# 35                        Zindagi  (1940)  120 min                      Drama
# 36                         Doctor  (1940)  144 min                      Drama
# 37                        Nartaki  (1940)  150 min                      Drama
# 38                  Diamond Queen  (1940)  155 min          Action, Adventure
# 39                         Padosi  (1941)  135 min                      Drama
# 40                      Khazanchi  (1941)  171 min                    Mystery
# 41  The Court Dancer: Raj Narkati  (1941)  144 min                      Drama
# 42                         Jhoola  (1941)  177 min                      Drama
# 43                          Bahen  (1941)  156 min                      Drama
# 44                          Jawab  (1942)  157 min                      Drama
# 45                      Meenakshi  (1942)  155 min                      Drama
# 46                         Basant  (1942)  146 min             Drama, Musical
# 47                   Bharat Milap  (1942)  170 min  Adventure, Drama, History
# 48                           Roti  (1942)  153 min                      Drama
# 49                       Khandaan  (1942)  171 min              Drama, Family
#
#     Rating Votes                    Director          Actor 1  \
# 0      6.2   112              Ardeshir Irani    Master Vithal
# 1      5.3     6      Bhagwati Prasad Mishra           Khalil
# 2      6.0    12                  J.J. Madan           Nissar
# 3      6.2    12                   John Hunt      Devika Rani
# 4      8.5     6      Mohan Dayaram Bhavnani            Bibbo
# 5      2.7    11              R.S. Choudhury       Ruby Mayer
# 6      7.4    38                 Debaki Bose      Durga Khote
# 7      6.3     9           Faredoon A. Irani         Aghajani
# 8      6.2     9           Premankur Atorthy       Rattan Bai
# 9      4.5    22                  Homi Wadia   Fearless Nadia
# 10     4.1    11  Shantaram Rajaram Vankudre   Nalini Tarkhad
# 11     7.3     6                 Franz Osten      Devika Rani
# 12     6.5   114                 Franz Osten      Devika Rani
# 13     6.2    91                  P.C. Barua      K.L. Saigal
# 14     6.1    17  Shantaram Rajaram Vankudre      Durga Khote
# 15     6.1    17                  Homi Wadia   Fearless Nadia
# 16     5.9     9                 Franz Osten      Devika Rani
# 17     3.1    10           Keshavrao Dhaiber   Nalini Tarkhad
# 18     7.0    23                 Debaki Bose    Pahadi Sanyal
# 19     6.9    31  Shantaram Rajaram Vankudre      Shanta Apte
# 20     6.7   229     Vishnupant Govind Damle  Sheikh Fattelal
# 21     6.3    12             Moti B. Gidwani        Padmadevi
# 22     5.9    12                 Franz Osten      Ashok Kumar
# 23     3.4    11                  Homi Wadia       John Cawas
# 24     7.2     8         Abdul Rashid Kardar     Bimla Kumari
# 25     6.4    10            Sarvottam Badami      Sabita Devi
# 26     6.3    15              Phani Majumdar      K.L. Saigal
# 27     5.5    14                 Franz Osten      Devika Rani
# 28     5.2     6                  Nitin Bose      K.L. Saigal
# 29     6.6     8                 Vijay Bhatt     Paidi Jairaj
# 30     6.4    11  Shantaram Rajaram Vankudre      Shahu Modak
# 31     8.1     9     Vishnupant Govind Damle  Sheikh Fattelal
# 32     7.9    45     Vishnupant Govind Damle  Sheikh Fattelal
# 33     7.2    30                Mehboob Khan         Surendra
# 34     7.1    11                N.R. Acharya    Leela Chitnis
# 35     7.0    12                  P.C. Barua      K.L. Saigal
# 36     6.5     6              Phani Majumdar     Subodh Mitra
# 37     6.5    11                 Debaki Bose      Leela Desai
# 38     6.1    31                  Homi Wadia   Fearless Nadia
# 39     7.2    12  Shantaram Rajaram Vankudre      Mazhar Khan
# 40     7.0    26             Moti B. Gidwani        M. Ismail
# 41     6.4    19                  Modhu Bose     Sadhona Bose
# 42     6.3    13              Gyan Mukherjee    Leela Chitnis
# 43     6.0    10                Mehboob Khan   Sheikh Mukhtar
# 44     7.6     8                  P.C. Barua   Ratin Banerjee
# 45     7.2    12                  Modhu Bose     Sadhona Bose
# 46     6.8    21           Amiya Chakrabarty    Mumtaz Shanti
# 47     6.6     9                 Vijay Bhatt        Prem Adib
# 48     6.3    30                Mehboob Khan    Chandra Mohan
# 49     6.2    14       Shaukat Hussain Rizvi       Noor Jehan
#
#                Actor 2              Actor 3
# 0              Zubeida                Jillo
# 1             Ermeline                Jillo
# 2      Jehanara Kajjan  Abdul Rehman Kabuli
# 3         Himanshu Rai       Abraham Sofaer
# 4      S.B. Nayampalli         Paidi Jairaj
# 5    Dinshaw Bilimoria                Jillo
# 6    Prithviraj Kapoor        Syed Mohammed
# 7      Jehanara Kajjan   Agha Jani Kashmiri
# 8       Master Vinayak         I.A. Hafizji
# 9              Sharifa              Gulshan
# 10     Sureshbabu Mane               Rajani
# 11         Ashok Kumar         Kamta Prasad
# 12         Ashok Kumar             Monorama
# 13          A.H. Shore        Pahadi Sanyal
# 14         Shanta Apte              Vasanti
# 15       Sardar Mansur         Sayani Atish
# 16         Ashok Kumar              Pramila
# 17    Nanasaheb Phatak          Shanta Apte
# 18  Durgadas Bannerjee           Chhayadevi
# 19      Keshavrao Date      Vimala Vasishta
# 20   Vishnupant Pagnis                Gauri
# 21               Jillo      Ghulam Mohammed
# 22          N.M. Joshi               Bilqis
# 23             Gulshan         Boman Shroff
# 24        B. Nandrekar          Sitara Devi
# 25             Motilal                Bibbo
# 26          Kanan Devi         Boken Chatto
# 27         Ashok Kumar            Maya Devi
# 28         Leela Desai              Devbala
# 29         Miss Mehtab          Shirin Banu
# 30     Shanta Hublikar           Sundarabai
# 31         Shahu Modak  Datta Dharmadhikari
# 32         Shahu Modak  Datta Dharmadhikari
# 33       Sardar Akhtar          Lala Yaqoob
# 34         Ashok Kumar         Hansa Wadkar
# 35       Pahadi Sanyal  Ashalata Wabgaonkar
# 36      Pankaj Mullick    Ahindra Choudhury
# 37     Bhanu Bannerjee       Najmul Hussain
# 38           Radharani               Nazira
# 39    Gajanan Jagirdar        Anees Khatoon
# 40              Ramola             Manorama
# 41    Protima Dasgupta         Binita Gupta
# 42         Ashok Kumar           Shah Nawaz
# 43      Nalini Jaywant               Harish
# 44          P.C. Barua    Ahindra Choudhury
# 45   Ahindra Choudhury      Rajlakshmi Devi
# 46               Ulhas           Mumtaz Ali
# 47       K.B. Athavale        Umakant Desai
# 48      Sheikh Mukhtar          Sitara Devi
# 49                Pran      Ghulam Mohammed

# %%
for year, group in top_10_movies_rating_per_year.groupby('Year'):
    plt.figure(figsize=(10, 6))
    plt.barh(group['Name'], group['Rating'], color='skyblue')
    plt.xlabel('Rating')
    plt.ylabel('Movie')
    plt.title(f'Top 10 Movies in {year} According to Rating')
    plt.gca().invert_yaxis()  # Invert y-axis to display top-rated movies at the top
    plt.show()

# %%
# plotting top 10 overall
plt.figure(figsize = (11,6))
plt.barh(top_10_overall['Name'], top_10_overall['Rating'], color = 'green')
plt.title("Top 10 Movies overall (by rating)")
plt.xlabel('Rating')
plt.ylabel('Movies')
plt.grid(axis = 'y')
plt.show()

# %%
# Calculating movies released by year

movies_released_yearly = data['Year'].value_counts()
top_years = movies_released_yearly.head(10)
top_years
# Out:
# Year
# (2019)    227
# (2017)    211
# (2018)    202
# (2015)    177
# (2016)    173
# (2013)    167
# (2014)    165
# (2005)    141
# (2012)    140
# (2020)    140
# Name: count, dtype: int64

# %%
plt.figure(figsize = (11,6))
plt.plot(top_years.index, top_years.values, color = 'orange', marker = 'o', linestyle = '--')
plt.title("Number of movies released each year")
plt.xlabel('Year')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
data['Year'] = data['Year'].str.strip('()').astype(int)

# %%
threshold_popularity = 6.0
popular_movies = data[data['Rating']>threshold_popularity]
popular_movies_count = popular_movies.groupby('Year').size()
popular_movies_count
# Out:
# Year
# 1931      1
# 1933      1
# 1934      1
# 1935      3
# 1936      5
#        ...
# 2017    109
# 2018    111
# 2019    130
# 2020     86
# 2021     40
# Length: 90, dtype: int64

# %%
plt.figure(figsize = (40,15))
plt.plot(popular_movies_count.index, popular_movies_count.values, color = 'purple', marker = 'o', linestyle = '--')
plt.title("Number of popular movies released each year")
plt.xlabel('Year')
plt.ylabel('Number of movies')
plt.xticks(popular_movies_count.index)
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
#Calculate the movies with highest rating per year
top_rated_movie = data.loc[data.groupby('Year')['Rating'].idxmax()]
top_rated_movie
# Out:
#                          Name  Year Duration             Genre  Rating Votes  \
# 14161  The Light of the World  1931  124 min    Drama, Fantasy     6.2   112
# 6073               Indrasabha  1932  211 min  Musical, Romance     6.0    12
# 4658                     Fate  1933   68 min    Drama, Romance     6.2    12
# 9053                  Mazdoor  1934  155 min             Drama     8.5     6
# 6087                 Inquilab  1935  144 min             Drama     7.4    38
# ...                       ...   ...      ...               ...     ...   ...
# 11841     Rediscovering India  2017  124 min       Documentary     9.0    62
# 1314             Ashok Vatika  2018   97 min             Drama     9.3     7
# 5077             Gho Gho Rani  2019  105 min  History, Romance     9.4    47
# 8339          Love Qubool Hai  2020   94 min    Drama, Romance    10.0     5
# 5410               Half Songs  2021   79 min    Music, Romance     9.7     7
#
#                      Director            Actor 1            Actor 2  \
# 14161          Ardeshir Irani      Master Vithal            Zubeida
# 6073               J.J. Madan             Nissar    Jehanara Kajjan
# 4658                John Hunt        Devika Rani       Himanshu Rai
# 9053   Mohan Dayaram Bhavnani              Bibbo    S.B. Nayampalli
# 6087              Debaki Bose        Durga Khote  Prithviraj Kapoor
# ...                       ...                ...                ...
# 11841            Meenal Dixit         Benny John         Benny John
# 1314            Rahul Mallick         Kunj Anand     Sanjay Bishnoi
# 5077             Munni Pankaj  Nishi Neha Mishra       Pankaj Kamal
# 8339          Saif Ali Sayeed          Ahaan Jha     Mahesh Narayan
# 5410              Sriram Raja       Raj Banerjee    Emon Chatterjee
#
#                    Actor 3
# 14161                Jillo
# 6073   Abdul Rehman Kabuli
# 4658        Abraham Sofaer
# 9053          Paidi Jairaj
# 6087         Syed Mohammed
# ...                    ...
# 11841         Meenal Dixit
# 1314          Paras Zutshi
# 5077           Akash Kumar
# 8339   Rajasree Rajakumari
# 5410     Purshottam Mulani
#
# [91 rows x 10 columns]

# %%
#Get the movies with highest rating overall
top_rated_overall = data.loc[data['Rating'].idxmax()]
top_rated_overall
# Out:
# Name            Love Qubool Hai
# Year                       2020
# Duration                 94 min
# Genre            Drama, Romance
# Rating                     10.0
# Votes                         5
# Director        Saif Ali Sayeed
# Actor 1               Ahaan Jha
# Actor 2          Mahesh Narayan
# Actor 3     Rajasree Rajakumari
# Name: 8339, dtype: object

# %%
# Calculating the number of votes

total_votes_yearly = top_rated_movie.groupby('Year')['Votes'].sum()
top_total_votes_yearly = total_votes_yearly.head(10)
top_total_votes_yearly
# Out:
# Year
# 1931    112
# 1932     12
# 1933     12
# 1934      6
# 1935     38
# 1936      6
# 1937     23
# 1938      8
# 1939      8
# 1940      9
# Name: Votes, dtype: object

# %%
plt.figure(figsize = (11,6))
plt.plot(top_total_votes_yearly.index, top_total_votes_yearly.values, color = 'red', marker = 'o', linestyle = '--')
plt.title("Number of votes per year")
plt.xlabel('Year')
plt.ylabel('Number of votes')
plt.grid(True)
plt.show()

# %%
director_count = data['Director'].value_counts()
top_15_director = director_count.head(15)
top_15_director
# Out:
# Director
# David Dhawan            41
# Mahesh Bhatt            39
# Ram Gopal Varma         33
# Hrishikesh Mukherjee    33
# Shakti Samanta          33
# Vikram Bhatt            30
# Priyadarshan            29
# Basu Chatterjee         23
# Rama Rao Tatineni       23
# Shyam Benegal           22
# Yash Chopra             22
# K. Bapaiah              22
# Kanti Shah              21
# Harmesh Malhotra        21
# Shyam Ramsay            20
# Name: count, dtype: int64

# %%
plt.figure(figsize = (35,6))
plt.bar(top_15_director.index, top_15_director.values, color = 'green', edgecolor = 'black')
for index, value in enumerate(top_15_director):
  plt.text(index, value + 0.1, str(value))
plt.title("Top 15 Director")
plt.xlabel("Director")
plt.ylabel('Count')
plt.show()

# %%
all_actors = pd.concat([data['Actor 1'], data['Actor 2'], data['Actor 3']])

# %%
# To calculate the count of all actors
all_actors_count = all_actors.value_counts()
top_actors_count = all_actors_count.head()
top_actors_count
# Out:
# Mithun Chakraborty    160
# Amitabh Bachchan      148
# Dharmendra            146
# Ashok Kumar           124
# Akshay Kumar          120
# Name: count, dtype: int64

# %%
plt.figure(figsize = (11,6))
plt.plot(top_actors_count.index, top_actors_count.values, color = 'Purple', marker = 'o', linestyle = '-')
plt.title("Top 5 actors")
plt.xlabel('Actors')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud
plt.subplots(figsize=(25,15))
wordcloud = WordCloud(
                          background_color='Black',
                          width=1920,
                          height=1080
                         ).generate(" ".join(all_actors))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('actor.png')
plt.show()

# %%
top_genre_count = data['Genre'].value_counts()
top_genre = top_genre_count.head()
top_genre
# Out:
# Genre
# Drama                   844
# Drama, Romance          332
# Action, Crime, Drama    329
# Action, Drama           206
# Comedy, Drama           205
# Name: count, dtype: int64
